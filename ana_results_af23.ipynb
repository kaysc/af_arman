# %%
import pandas as pd
import os
import glob
import json
import numpy as np
import shutil
from Bio import SeqIO
from pymol import cmd
from pymol import CmdException

# %%
def check_ligand_location_pymol(pdb_file, id, prot_chain="B", pep_chain="C", debug=False, out_pdb=""):
    ref_pdb = "input_files/ref_gpcr.pdb"

    cmd.reinitialize()
    cmd.load(pdb_file, "struct")
    cmd.load(ref_pdb, "ref")
    #cmd.do('tmalign struct and chain %s, ref' % prot_chain)
    cmd.cealign("ref", 'struct and chain %s' % prot_chain) # OBS CEalign has target and mobile inverted
    com_prot = [round(x, 3) for x in cmd.centerofmass('struct and chain %s' % prot_chain)]
    com_pep = [round(x, 3) for x in cmd.centerofmass('struct and chain %s' % pep_chain)]

    if debug:
        print("> %s" % pdb_file)
        cmd.color("silver", "chain %s and elem C" % prot_chain)
        cmd.show("spheres", "chain %s" % pep_chain)
        cmd.hide("cartoon", "chain %s" % pep_chain)
        print("\tCOM prot:", com_prot)
        print("\t COM pep: ", com_pep)
        pse_file = "debug.pse"
        cmd.save(pse_file)
    else:
        cmd.delete("ref")

    if com_prot[2] > com_pep[2]:
        is_outside = True
    else:
        is_outside = False

    if debug:
        print("\t> Is_outside:", is_outside)
    if prot_chain == "B" and pep_chain == "C":
        cmd.alter("chain B", "chain=\"A\"")
        cmd.alter("chain C", "chain=\"B\"")
        cmd.alter("chain D", "chain=\"C\"")

    if out_pdb != "":
        cmd.save(out_pdb, "struct")
    return is_outside

# %%
results_dir = "af_jobs_af23"
out_dir = "output_files_af23/"
out_csv = "%s/af_results.csv" % out_dir
pdb_out_dir = "%s/individual_pdbs" % out_dir
for filename in glob.glob("%s/*.pdb" % pdb_out_dir): os.remove(filename)

results_data = pd.DataFrame()
for job_dir in sorted(glob.glob("%s/*/*/" % results_dir)):
    _, rec, lig, _ = job_dir.split("/")
    comp = "%s-%s" % (rec, lig)

    outside_found = False
    outside_pdb = np.nan
    rank = np.nan
    finished = False
    score = np.nan
    relaxed_struct = False
    has_x = False

    if os.path.exists("%s/%s/ranked_0.pdb" % (job_dir, comp)):
        print(rec, lig, "finished")

        fasta_entry = SeqIO.parse(open("%s/%s.fasta" % (job_dir, comp)), "fasta")
        for record in fasta_entry:
            if "X" in record.seq:
                has_x = True
        finished = True

        with open("%s/%s/ranking_debug.json" % (job_dir, comp), "r") as json_file:
            ranking_data = json.load(json_file)

        outside_pdb = "%s/%s/first_outside.pdb" % (job_dir, comp)
        for pdb_file in sorted(glob.glob(job_dir+"%s/ranked_*.pdb" % (comp))):
            if has_x:
                is_outside = check_ligand_location_pymol(pdb_file=pdb_file, id=comp, prot_chain="B", pep_chain="C",
                                                         out_pdb=outside_pdb)
                relaxed = False
            else:
                try:
                    is_outside = check_ligand_location_pymol(pdb_file=pdb_file, id=comp, prot_chain="A", pep_chain="B",
                                                             out_pdb=outside_pdb)
                    relaxed = True
                except CmdException:
                    is_outside = check_ligand_location_pymol(pdb_file=pdb_file, id=comp, prot_chain="B", pep_chain="C",
                                                             out_pdb=outside_pdb)
                    relaxed=False

            if is_outside:
                print("\t%s *is* outside" % (pdb_file.split("/")[-1]))
                outside_found = True
                rank = pdb_file.split("_")[-1].split(".")[0]
                out_pdb = "%s/%s-%s-rank%s.pdb" % (pdb_out_dir, rec, lig, rank)
                score = round(ranking_data["iptm+ptm"]["model_%s_multimer_v3_pred_0" % (int(rank)+1)], 2)
                shutil.copy(outside_pdb, out_pdb)
                break
            else:
                #print("\t%s is NOT outside" % (pdb_file.split("/")[-1]))
                pass

    else:
        print(rec, lig, "NOT finished")

    tmp_data = {"complex": comp, "finished": finished, "receptor": rec, "ligand": lig,
                                       "outside_found": outside_found, "chosen_rank": rank,
                                       "score": score, "relaxed": relaxed}
    tmp_data = pd.DataFrame.from_dict(tmp_data, orient="index").T.set_index("complex")
    results_data = pd.concat([results_data, tmp_data])

results_data.to_csv(out_csv)
shutil.make_archive("%s/all_chosen_pdbs" % out_dir, 'zip', pdb_out_dir)
# Out:
# 5ht1b_human 137 finished
# 	ranked_4.pdb *is* outside
# 5ht1d_human 137 finished
# 	ranked_4.pdb *is* outside
# ackr1_human 753 finished
# 	ranked_0.pdb *is* outside
# ackr1_human 758 finished
# 	ranked_0.pdb *is* outside
# ackr1_human 759 finished
# 	ranked_0.pdb *is* outside
# ackr1_human 769 finished
# 	ranked_0.pdb *is* outside
# ackr1_human 771 finished
# 	ranked_0.pdb *is* outside
# ackr1_human 797 finished
# 	ranked_0.pdb *is* outside
# ackr1_human 820 finished
# 	ranked_0.pdb *is* outside
# ackr1_human 821 finished
# 	ranked_0.pdb *is* outside
# ackr1_human 829 finished
# 	ranked_0.pdb *is* outside
# ackr1_human 836 finished
# 	ranked_0.pdb *is* outside
# ackr2_human 753 finished
# 	ranked_0.pdb *is* outside
# ackr2_human 756 finished
# 	ranked_0.pdb *is* outside
# ackr2_human 757 finished
# 	ranked_0.pdb *is* outside
# ackr2_human 758 finished
# 	ranked_0.pdb *is* outside
# ackr2_human 759 finished
# 	ranked_0.pdb *is* outside
# ackr2_human 769 finished
# 	ranked_0.pdb *is* outside
# ackr2_human 770 finished
# 	ranked_0.pdb *is* outside
# ackr2_human 771 finished
# 	ranked_0.pdb *is* outside
# ackr2_human 772 finished
# 	ranked_0.pdb *is* outside
# ackr2_human 797 finished
# 	ranked_0.pdb *is* outside
# ackr2_human 798 finished
# 	ranked_0.pdb *is* outside
# ackr3_human 4358 finished
# 	ranked_0.pdb *is* outside
# ackr3_human 836 finished
# 	ranked_0.pdb *is* outside
# ackr3_rat 697 finished
# 	ranked_0.pdb *is* outside
# ackr4_human 810 finished
# 	ranked_0.pdb *is* outside
# ackr4_human 811 finished
# 	ranked_0.pdb *is* outside
# ackr4_human 817 finished
# 	ranked_0.pdb *is* outside
# acthr_human 3633 finished
# 	ranked_0.pdb *is* outside
# acthr_mouse 1331 finished
# 	ranked_0.pdb *is* outside
# agtr1_human 2504 finished
# 	ranked_0.pdb *is* outside
# agtr1_human 5368 finished
# 	ranked_0.pdb *is* outside
# agtr1_human 585 finished
# 	ranked_0.pdb *is* outside
# agtr1_human 6894 finished
# 	ranked_0.pdb *is* outside
# agtr2_human 2504 finished
# 	ranked_0.pdb *is* outside
# agtr2_human 5578 finished
# 	ranked_0.pdb *is* outside
# agtr2_human 585 finished
# 	ranked_0.pdb *is* outside
# agtrb_rat 6894 finished
# 	ranked_0.pdb *is* outside
# apj_human 3555 finished
# 	ranked_0.pdb *is* outside
# apj_human 3556 finished
# 	ranked_0.pdb *is* outside
# apj_human 599 finished
# 	ranked_0.pdb *is* outside
# apj_human 602 finished
# 	ranked_0.pdb *is* outside
# apj_human 606 finished
# 	ranked_0.pdb *is* outside
# apj_human 7930 finished
# 	ranked_0.pdb *is* outside
# apj_human 7931 finished
# 	ranked_0.pdb *is* outside
# apj_human 8525 finished
# 	ranked_0.pdb *is* outside
# apj_human 8526 finished
# 	ranked_0.pdb *is* outside
# bkrb1_human 3578 finished
# 	ranked_0.pdb *is* outside
# bkrb1_human 3580 finished
# 	ranked_0.pdb *is* outside
# bkrb1_human 3812 finished
# 	ranked_0.pdb *is* outside
# bkrb1_human 3825 finished
# 	ranked_0.pdb *is* outside
# bkrb1_human 639 finished
# 	ranked_0.pdb *is* outside
# bkrb1_human 646 finished
# 	ranked_0.pdb *is* outside
# bkrb1_human 650 finished
# 	ranked_0.pdb *is* outside
# bkrb1_mouse 3812 finished
# 	ranked_0.pdb *is* outside
# bkrb1_mouse 3825 finished
# 	ranked_0.pdb *is* outside
# bkrb1_mouse 646 finished
# 	ranked_0.pdb *is* outside
# bkrb1_mouse 650 finished
# 	ranked_0.pdb *is* outside
# bkrb1_rat 3812 finished
# 	ranked_0.pdb *is* outside
# bkrb1_rat 3825 finished
# 	ranked_0.pdb *is* outside
# bkrb1_rat 639 finished
# 	ranked_0.pdb *is* outside
# bkrb1_rat 650 finished
# 	ranked_0.pdb *is* outside
# bkrb2_human 3578 finished
# 	ranked_0.pdb *is* outside
# bkrb2_human 3580 finished
# 	ranked_0.pdb *is* outside
# bkrb2_human 3812 finished
# 	ranked_0.pdb *is* outside
# bkrb2_human 3825 finished
# 	ranked_0.pdb *is* outside
# bkrb2_human 639 finished
# 	ranked_0.pdb *is* outside
# bkrb2_human 646 finished
# 	ranked_0.pdb *is* outside
# bkrb2_human 650 finished
# 	ranked_0.pdb *is* outside
# bkrb2_mouse 3812 finished
# 	ranked_0.pdb *is* outside
# bkrb2_mouse 646 finished
# 	ranked_0.pdb *is* outside
# bkrb2_mouse 650 finished
# 	ranked_0.pdb *is* outside
# c3ar_human 3576 finished
# 	ranked_0.pdb *is* outside
# c3ar_human 3577 finished
# 	ranked_0.pdb *is* outside
# c3ar_human 3640 finished
# 	ranked_0.pdb *is* outside
# c3ar_human 3641 finished
# 	ranked_0.pdb *is* outside
# c3ar_human 3642 finished
# 	ranked_0.pdb *is* outside
# c3ar_human 573 finished
# 	ranked_0.pdb *is* outside
# c5ar1_human 3576 finished
# 	ranked_0.pdb *is* outside
# c5ar1_human 3577 finished
# 	ranked_0.pdb *is* outside
# c5ar1_human 3640 finished
# 	ranked_0.pdb *is* outside
# c5ar1_human 3641 finished
# 	ranked_0.pdb *is* outside
# c5ar1_human 3642 finished
# 	ranked_0.pdb *is* outside
# c5ar1_human 3728 finished
# 	ranked_0.pdb *is* outside
# c5ar1_human 573 finished
# 	ranked_0.pdb *is* outside
# c5ar1_human 574 finished
# 	ranked_0.pdb *is* outside
# c5ar2_human 573 finished
# 	ranked_0.pdb *is* outside
# c5ar2_human 574 finished
# 	ranked_0.pdb *is* outside
# cckar_human 10221 finished
# 	ranked_0.pdb *is* outside
# cckar_human 3550 finished
# 	ranked_0.pdb *is* outside
# cckar_human 3551 finished
# 	ranked_0.pdb *is* outside
# cckar_human 3552 finished
# 	ranked_0.pdb *is* outside
# cckar_human 3559 finished
# 	ranked_0.pdb *is* outside
# cckar_human 3560 finished
# 	ranked_1.pdb *is* outside
# cckar_human 3561 finished
# 	ranked_0.pdb *is* outside
# cckar_human 860 finished
# 	ranked_0.pdb *is* outside
# cckar_human 861 finished
# 	ranked_0.pdb *is* outside
# cckar_human 864 finished
# 	ranked_0.pdb *is* outside
# cckar_rat 860 finished
# 	ranked_0.pdb *is* outside
# cckar_rat 864 finished
# 	ranked_0.pdb *is* outside
# ccr10_human 3646 finished
# 	ranked_0.pdb *is* outside
# ccr10_human 3649 finished
# 	ranked_0.pdb *is* outside
# ccr10_human 4462 finished
# 	ranked_0.pdb *is* outside
# ccr10_human 4463 finished
# 	ranked_0.pdb *is* outside
# ccr1_human 1272 finished
# 	ranked_0.pdb *is* outside
# ccr1_human 4408 finished
# 	ranked_0.pdb *is* outside
# ccr1_human 4409 finished
# 	ranked_0.pdb *is* outside
# ccr1_human 4410 finished
# 	ranked_0.pdb *is* outside
# ccr1_human 4411 finished
# 	ranked_0.pdb *is* outside
# ccr1_human 4412 finished
# 	ranked_0.pdb *is* outside
# ccr1_human 4413 finished
# 	ranked_0.pdb *is* outside
# ccr1_human 4414 finished
# 	ranked_0.pdb *is* outside
# ccr1_human 4415 finished
# 	ranked_0.pdb *is* outside
# ccr1_human 753 finished
# 	ranked_0.pdb *is* outside
# ccr1_human 754 finished
# 	ranked_0.pdb *is* outside
# ccr1_human 755 finished
# 	ranked_0.pdb *is* outside
# ccr1_human 756 finished
# 	ranked_0.pdb *is* outside
# ccr1_human 757 finished
# 	ranked_0.pdb *is* outside
# ccr1_human 758 finished
# 	ranked_0.pdb *is* outside
# ccr1_human 759 finished
# 	ranked_0.pdb *is* outside
# ccr1_human 770 finished
# 	ranked_0.pdb *is* outside
# ccr1_human 772 finished
# 	ranked_0.pdb *is* outside
# ccr2_human 1272 finished
# 	ranked_0.pdb *is* outside
# ccr2_human 4406 finished
# 	ranked_0.pdb *is* outside
# ccr2_human 4407 finished
# 	ranked_0.pdb *is* outside
# ccr2_human 4413 finished
# 	ranked_0.pdb *is* outside
# ccr2_human 4414 finished
# 	ranked_0.pdb *is* outside
# ccr2_human 4415 finished
# 	ranked_0.pdb *is* outside
# ccr2_human 4416 finished
# 	ranked_0.pdb *is* outside
# ccr2_human 759 finished
# 	ranked_0.pdb *is* outside
# ccr2_human 769 finished
# 	ranked_0.pdb *is* outside
# ccr2_human 770 finished
# 	ranked_0.pdb *is* outside
# ccr2_human 771 finished
# 	ranked_0.pdb *is* outside
# ccr2_human 772 finished
# 	ranked_0.pdb *is* outside
# ccr2_human 775 finished
# 	ranked_0.pdb *is* outside
# ccr2_human 776 finished
# 	ranked_0.pdb *is* outside
# ccr2_human 787 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 3649 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 4406 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 4407 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 4412 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 4413 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 4414 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 4415 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 4416 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 4421 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 4429 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 4430 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 4431 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 4432 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 4463 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 754 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 758 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 759 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 769 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 770 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 771 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 772 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 775 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 776 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 787 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 835 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 836 finished
# 	ranked_0.pdb *is* outside
# ccr3_human 837 finished
# 	ranked_0.pdb *is* outside
# ccr4_human 4420 finished
# 	ranked_0.pdb *is* outside
# ccr4_human 797 finished
# 	ranked_0.pdb *is* outside
# ccr4_human 798 finished
# 	ranked_0.pdb *is* outside
# ccr5_human 1272 finished
# 	ranked_0.pdb *is* outside
# ccr5_human 4406 finished
# 	ranked_0.pdb *is* outside
# ccr5_human 4407 finished
# 	ranked_0.pdb *is* outside
# ccr5_human 4408 finished
# 	ranked_0.pdb *is* outside
# ccr5_human 4409 finished
# 	ranked_0.pdb *is* outside
# ccr5_human 4410 finished
# 	ranked_0.pdb *is* outside
# ccr5_human 4411 finished
# 	ranked_0.pdb *is* outside
# ccr5_human 4412 finished
# 	ranked_0.pdb *is* outside
# ccr5_human 4413 finished
# 	ranked_0.pdb *is* outside
# ccr5_human 4414 finished
# 	ranked_0.pdb *is* outside
# ccr5_human 4415 finished
# 	ranked_0.pdb *is* outside
# ccr5_human 4416 finished
# 	ranked_0.pdb *is* outside
# ccr5_human 753 finished
# 	ranked_0.pdb *is* outside
# ccr5_human 756 finished
# 	ranked_0.pdb *is* outside
# ccr5_human 757 finished
# 	ranked_0.pdb *is* outside
# ccr5_human 758 finished
# 	ranked_0.pdb *is* outside
# ccr5_human 759 finished
# 	ranked_0.pdb *is* outside
# ccr5_human 769 finished
# 	ranked_0.pdb *is* outside
# ccr5_human 770 finished
# 	ranked_0.pdb *is* outside
# ccr5_human 771 finished
# 	ranked_0.pdb *is* outside
# ccr5_human 772 finished
# 	ranked_0.pdb *is* outside
# ccr5_human 787 finished
# 	ranked_0.pdb *is* outside
# ccr6_human 3648 finished
# ccr6_human 4418 finished
# 	ranked_0.pdb *is* outside
# ccr6_human 4419 finished
# 	ranked_0.pdb *is* outside
# ccr6_human 808 finished
# 	ranked_0.pdb *is* outside
# ccr7_human 810 finished
# 	ranked_0.pdb *is* outside
# ccr7_human 811 finished
# 	ranked_0.pdb *is* outside
# ccr7_human 8652 finished
# 	ranked_0.pdb *is* outside
# ccr7_mouse 4417 finished
# 	ranked_0.pdb *is* outside
# ccr7_mouse 8651 finished
# 	ranked_0.pdb *is* outside
# ccr7_mouse 8652 finished
# 	ranked_0.pdb *is* outside
# ccr8_human 4404 finished
# 	ranked_0.pdb *is* outside
# ccr8_human 4415 finished
# 	ranked_0.pdb *is* outside
# ccr8_human 812 finished
# 	ranked_0.pdb *is* outside
# ccr9_human 4422 finished
# 	ranked_0.pdb *is* outside
# ccr9_human 817 finished
# 	ranked_0.pdb *is* outside
# ccrl2_human 3422 finished
# 	ranked_0.pdb *is* outside
# ccrl2_human 4417 finished
# 	ranked_0.pdb *is* outside
# ccrl2_human 810 finished
# 	ranked_0.pdb *is* outside
# cml1_human 2945 finished
# 	ranked_0.pdb *is* outside
# cml1_human 3422 finished
# 	ranked_0.pdb *is* outside
# cml2_human 2945 finished
# 	ranked_0.pdb *is* outside
# cx3c1_human 4468 finished
# 	ranked_0.pdb *is* outside
# cx3c1_human 4469 finished
# 	ranked_0.pdb *is* outside
# cx3c1_human 856 finished
# 	ranked_0.pdb *is* outside
# cxcr1_human 3729 finished
# 	ranked_0.pdb *is* outside
# cxcr1_human 820 finished
# 	ranked_0.pdb *is* outside
# cxcr1_human 821 finished
# 	ranked_0.pdb *is* outside
# cxcr2_human 4423 finished
# 	ranked_0.pdb *is* outside
# cxcr2_human 4424 finished
# 	ranked_0.pdb *is* outside
# cxcr2_human 4425 finished
# 	ranked_0.pdb *is* outside
# cxcr2_human 4426 finished
# 	ranked_0.pdb *is* outside
# cxcr2_human 4427 finished
# 	ranked_0.pdb *is* outside
# cxcr2_human 4428 finished
# 	ranked_0.pdb *is* outside
# cxcr2_human 4464 finished
# 	ranked_0.pdb *is* outside
# cxcr2_human 819 finished
# 	ranked_0.pdb *is* outside
# cxcr2_human 820 finished
# 	ranked_0.pdb *is* outside
# cxcr2_human 821 finished
# 	ranked_0.pdb *is* outside
# cxcr2_human 826 finished
# 	ranked_0.pdb *is* outside
# cxcr2_human 827 finished
# 	ranked_0.pdb *is* outside
# cxcr2_human 828 finished
# 	ranked_0.pdb *is* outside
# cxcr2_human 829 finished
# 	ranked_0.pdb *is* outside
# cxcr2_human 830 finished
# 	ranked_0.pdb *is* outside
# cxcr2_mouse 819 finished
# 	ranked_0.pdb *is* outside
# cxcr2_mouse 821 finished
# 	ranked_0.pdb *is* outside
# cxcr3_human 4358 finished
# 	ranked_0.pdb *is* outside
# cxcr3_human 4429 finished
# 	ranked_0.pdb *is* outside
# cxcr3_human 4430 finished
# 	ranked_0.pdb *is* outside
# cxcr3_human 4431 finished
# 	ranked_0.pdb *is* outside
# cxcr3_human 4432 finished
# 	ranked_0.pdb *is* outside
# cxcr3_human 758 finished
# 	ranked_0.pdb *is* outside
# cxcr3_human 759 finished
# 	ranked_0.pdb *is* outside
# cxcr3_human 769 finished
# 	ranked_0.pdb *is* outside
# cxcr3_human 770 finished
# 	ranked_0.pdb *is* outside
# cxcr3_human 808 finished
# 	ranked_0.pdb *is* outside
# cxcr3_human 810 finished
# 	ranked_0.pdb *is* outside
# cxcr3_human 835 finished
# 	ranked_0.pdb *is* outside
# cxcr3_human 836 finished
# 	ranked_0.pdb *is* outside
# cxcr3_human 837 finished
# 	ranked_0.pdb *is* outside
# cxcr4_human 4358 finished
# 	ranked_0.pdb *is* outside
# cxcr4_human 4465 finished
# 	ranked_0.pdb *is* outside
# cxcr4_human 845 finished
# 	ranked_0.pdb *is* outside
# cxcr4_human 8530 finished
# 	ranked_0.pdb *is* outside
# cxcr4_human 8531 finished
# 	ranked_0.pdb *is* outside
# cxcr4_human 8532 finished
# 	ranked_0.pdb *is* outside
# cxcr4_human 8533 finished
# 	ranked_0.pdb *is* outside
# cxcr5_human 3645 finished
# 	ranked_0.pdb *is* outside
# cxcr5_human 4466 finished
# 	ranked_0.pdb *is* outside
# cxcr6_human 4433 finished
# 	ranked_0.pdb *is* outside
# cxcr6_human 4467 finished
# 	ranked_0.pdb *is* outside
# cxcr6_human 855 finished
# 	ranked_0.pdb *is* outside
# ednra_human 1004 finished
# 	ranked_0.pdb *is* outside
# ednra_human 3546 finished
# 	ranked_0.pdb *is* outside
# ednra_human 989 finished
# 	ranked_0.pdb *is* outside
# ednra_human 990 finished
# 	ranked_0.pdb *is* outside
# ednrb_human 1004 finished
# 	ranked_0.pdb *is* outside
# ednrb_human 3546 finished
# 	ranked_0.pdb *is* outside
# ednrb_human 989 finished
# 	ranked_0.pdb *is* outside
# ednrb_human 990 finished
# 	ranked_0.pdb *is* outside
# ednrb_rat 1004 finished
# 	ranked_0.pdb *is* outside
# fpr1_human 1022 finished
# 	ranked_0.pdb *is* outside
# fpr1_human 1026 finished
# 	ranked_0.pdb *is* outside
# fpr1_human 1031 finished
# fpr1_human 3568 finished
# fpr1_human 3569 finished
# fpr1_human 3570 finished
# 	ranked_0.pdb *is* outside
# fpr1_human 3571 finished
# 	ranked_3.pdb *is* outside
# fpr1_human 3572 finished
# 	ranked_0.pdb *is* outside
# fpr1_mouse 1026 finished
# 	ranked_0.pdb *is* outside
# fpr2_human 1022 finished
# 	ranked_0.pdb *is* outside
# fpr2_human 1031 finished
# fpr2_human 1047 finished
# 	ranked_0.pdb *is* outside
# fpr2_human 3568 finished
# fpr2_human 3569 finished
# fpr2_human 5527 finished
# 	ranked_0.pdb *is* outside
# fpr2_human 6242 finished
# 	ranked_0.pdb *is* outside
# fpr2_human 6244 finished
# 	ranked_0.pdb *is* outside
# fpr2_mouse 1047 finished
# 	ranked_0.pdb *is* outside
# fpr2_mouse 6266 finished
# 	ranked_0.pdb *is* outside
# fpr3_human 1044 finished
# 	ranked_0.pdb *is* outside
# fpr3_human 1047 finished
# 	ranked_0.pdb *is* outside
# fpr3_human 3574 finished
# 	ranked_0.pdb *is* outside
# fpr3_human 3935 finished
# 	ranked_0.pdb *is* outside
# fshr_human 1157 finished
# g37l1_human 6067 finished
# galr1_human 3593 finished
# 	ranked_0.pdb *is* outside
# galr1_human 3594 finished
# 	ranked_0.pdb *is* outside
# galr1_human 3595 finished
# 	ranked_0.pdb *is* outside
# galr1_human 3596 finished
# 	ranked_0.pdb *is* outside
# galr1_human 6090 finished
# 	ranked_0.pdb *is* outside
# galr1_mouse 3593 finished
# 	ranked_0.pdb *is* outside
# galr1_rat 3593 finished
# 	ranked_0.pdb *is* outside
# galr1_rat 6090 finished
# 	ranked_0.pdb *is* outside
# galr2_human 11417 finished
# 	ranked_0.pdb *is* outside
# galr2_human 3593 finished
# 	ranked_0.pdb *is* outside
# galr2_human 3594 finished
# 	ranked_0.pdb *is* outside
# galr2_human 3595 finished
# 	ranked_0.pdb *is* outside
# galr2_human 3596 finished
# 	ranked_0.pdb *is* outside
# galr2_human 6090 finished
# 	ranked_0.pdb *is* outside
# galr2_mouse 3593 finished
# 	ranked_0.pdb *is* outside
# galr2_rat 3593 finished
# 	ranked_0.pdb *is* outside
# galr2_rat 6090 finished
# 	ranked_0.pdb *is* outside
# galr3_human 11417 finished
# 	ranked_0.pdb *is* outside
# galr3_human 3593 finished
# 	ranked_0.pdb *is* outside
# galr3_human 3594 finished
# 	ranked_0.pdb *is* outside
# galr3_human 3595 finished
# 	ranked_0.pdb *is* outside
# galr3_human 3596 finished
# 	ranked_0.pdb *is* outside
# galr3_human 6090 finished
# 	ranked_0.pdb *is* outside
# galr3_rat 3593 finished
# 	ranked_0.pdb *is* outside
# galr3_rat 6090 finished
# 	ranked_0.pdb *is* outside
# gasr_human 10221 finished
# 	ranked_0.pdb *is* outside
# gasr_human 3550 finished
# 	ranked_0.pdb *is* outside
# gasr_human 3551 finished
# 	ranked_1.pdb *is* outside
# gasr_human 3552 finished
# 	ranked_2.pdb *is* outside
# gasr_human 3560 finished
# 	ranked_4.pdb *is* outside
# gasr_human 3561 finished
# 	ranked_0.pdb *is* outside
# gasr_human 8408 finished
# 	ranked_0.pdb *is* outside
# gasr_human 8409 finished
# 	ranked_0.pdb *is* outside
# gasr_human 8410 finished
# 	ranked_0.pdb *is* outside
# gasr_human 8411 finished
# gasr_human 860 finished
# 	ranked_2.pdb *is* outside
# gasr_human 861 finished
# 	ranked_0.pdb *is* outside
# gasr_human 864 finished
# 	ranked_0.pdb *is* outside
# gasr_mouse 3559 finished
# 	ranked_2.pdb *is* outside
# ghsr_human 1099 finished
# 	ranked_0.pdb *is* outside
# ghsr_human 3597 finished
# 	ranked_0.pdb *is* outside
# ghsr_human 3600 finished
# 	ranked_0.pdb *is* outside
# ghsr_human 3601 finished
# 	ranked_0.pdb *is* outside
# gnrhr_human 1162 finished
# 	ranked_0.pdb *is* outside
# gnrhr_human 1164 finished
# 	ranked_0.pdb *is* outside
# gnrhr_mouse 1162 finished
# 	ranked_0.pdb *is* outside
# gnrhr_rat 1162 finished
# 	ranked_0.pdb *is* outside
# gp182_rat 697 finished
# 	ranked_0.pdb *is* outside
# gpr15_human 10567 finished
# 	ranked_0.pdb *is* outside
# gpr15_human 10568 finished
# 	ranked_0.pdb *is* outside
# gpr37_human 6067 finished
# gpr39_human 1579 finished
# 	ranked_2.pdb *is* outside
# gpr39_human 5336 finished
# gpr39_human 5337 finished
# gpr75_human 758 finished
# 	ranked_2.pdb *is* outside
# grpr_human 3582 finished
# 	ranked_0.pdb *is* outside
# grpr_human 3583 finished
# 	ranked_0.pdb *is* outside
# grpr_human 612 finished
# 	ranked_0.pdb *is* outside
# grpr_human 613 finished
# 	ranked_0.pdb *is* outside
# grpr_human 6175 finished
# 	ranked_0.pdb *is* outside
# grpr_mouse 612 finished
# 	ranked_0.pdb *is* outside
# grpr_mouse 613 finished
# 	ranked_0.pdb *is* outside
# grpr_rat 612 finished
# 	ranked_0.pdb *is* outside
# grpr_rat 613 finished
# 	ranked_0.pdb *is* outside
# grpr_rat 6178 finished
# 	ranked_0.pdb *is* outside
# hrh4_human 1272 finished
# kissr_human 1281 finished
# 	ranked_0.pdb *is* outside
# kissr_human 1284 finished
# 	ranked_0.pdb *is* outside
# kissr_human 1285 finished
# 	ranked_0.pdb *is* outside
# kissr_human 1288 finished
# 	ranked_0.pdb *is* outside
# kissr_human 3709 finished
# 	ranked_0.pdb *is* outside
# kissr_human 3710 finished
# 	ranked_0.pdb *is* outside
# kissr_human 3711 finished
# 	ranked_0.pdb *is* outside
# kissr_rat 1281 finished
# 	ranked_0.pdb *is* outside
# kissr_rat 1284 finished
# 	ranked_0.pdb *is* outside
# kissr_rat 1285 finished
# 	ranked_0.pdb *is* outside
# kissr_rat 1288 finished
# 	ranked_0.pdb *is* outside
# lgr4_human 3697 finished
# 	ranked_0.pdb *is* outside
# lgr4_human 3698 finished
# 	ranked_0.pdb *is* outside
# lgr4_human 3699 finished
# 	ranked_0.pdb *is* outside
# lgr4_human 3700 finished
# 	ranked_0.pdb *is* outside
# lgr5_human 3697 finished
# 	ranked_0.pdb *is* outside
# lgr5_human 3698 finished
# 	ranked_0.pdb *is* outside
# lgr5_human 3699 finished
# 	ranked_0.pdb *is* outside
# lgr5_human 3700 finished
# 	ranked_0.pdb *is* outside
# lgr6_human 3697 finished
# 	ranked_0.pdb *is* outside
# lgr6_human 3698 finished
# 	ranked_0.pdb *is* outside
# lgr6_human 3699 finished
# 	ranked_0.pdb *is* outside
# lgr6_human 3700 finished
# 	ranked_0.pdb *is* outside
# lshr_human 1159 finished
# 	ranked_0.pdb *is* outside
# lshr_human 1160 finished
# 	ranked_0.pdb *is* outside
# mc3r_human 1320 finished
# 	ranked_0.pdb *is* outside
# mc3r_human 1331 finished
# 	ranked_0.pdb *is* outside
# mc3r_human 1333 finished
# 	ranked_0.pdb *is* outside
# mc3r_human 1335 finished
# 	ranked_0.pdb *is* outside
# mc3r_human 3606 finished
# 	ranked_0.pdb *is* outside
# mc3r_human 3607 finished
# 	ranked_0.pdb *is* outside
# mc3r_human 3608 finished
# 	ranked_0.pdb *is* outside
# mc3r_human 3633 finished
# 	ranked_0.pdb *is* outside
# mc3r_mouse 1329 finished
# 	ranked_0.pdb *is* outside
# mc4r_human 1320 finished
# 	ranked_0.pdb *is* outside
# mc4r_human 1331 finished
# 	ranked_0.pdb *is* outside
# mc4r_human 1333 finished
# 	ranked_0.pdb *is* outside
# mc4r_human 1335 finished
# 	ranked_0.pdb *is* outside
# mc4r_human 3606 finished
# 	ranked_0.pdb *is* outside
# mc4r_human 3607 finished
# 	ranked_0.pdb *is* outside
# mc4r_human 3608 finished
# 	ranked_0.pdb *is* outside
# mc4r_human 3633 finished
# 	ranked_0.pdb *is* outside
# mc4r_mouse 1329 finished
# 	ranked_0.pdb *is* outside
# mc5r_human 1320 finished
# 	ranked_0.pdb *is* outside
# mc5r_human 1331 finished
# 	ranked_0.pdb *is* outside
# mc5r_human 1333 finished
# 	ranked_0.pdb *is* outside
# mc5r_human 1335 finished
# 	ranked_0.pdb *is* outside
# mc5r_human 3606 finished
# 	ranked_0.pdb *is* outside
# mc5r_human 3607 finished
# 	ranked_0.pdb *is* outside
# mc5r_human 3608 finished
# 	ranked_0.pdb *is* outside
# mc5r_human 3633 finished
# 	ranked_0.pdb *is* outside
# mc5r_mouse 1329 finished
# 	ranked_0.pdb *is* outside
# mchr1_human 1298 finished
# 	ranked_0.pdb *is* outside
# mchr1_rat 1298 finished
# 	ranked_0.pdb *is* outside
# mchr2_human 1298 finished
# 	ranked_0.pdb *is* outside
# mrgx1_human 4058 finished
# 	ranked_0.pdb *is* outside
# mrgx2_human 4057 finished
# 	ranked_0.pdb *is* outside
# mshr_human 1320 finished
# 	ranked_0.pdb *is* outside
# mshr_human 1331 finished
# 	ranked_0.pdb *is* outside
# mshr_human 1333 finished
# 	ranked_0.pdb *is* outside
# mshr_human 3606 finished
# 	ranked_0.pdb *is* outside
# mshr_human 3607 finished
# 	ranked_0.pdb *is* outside
# mshr_human 3608 finished
# 	ranked_0.pdb *is* outside
# mshr_human 3633 finished
# 	ranked_0.pdb *is* outside
# mshr_mouse 1329 finished
# 	ranked_0.pdb *is* outside
# mtlr_human 3794 finished
# 	ranked_0.pdb *is* outside
# nk1r_human 2087 finished
# 	ranked_0.pdb *is* outside
# nk1r_human 2090 finished
# 	ranked_0.pdb *is* outside
# nk1r_human 2091 finished
# 	ranked_0.pdb *is* outside
# nk1r_human 2092 finished
# 	ranked_0.pdb *is* outside
# nk1r_human 3795 finished
# 	ranked_0.pdb *is* outside
# nk1r_human 3835 finished
# 	ranked_0.pdb *is* outside
# nk2r_cavpo 2091 finished
# 	ranked_0.pdb *is* outside
# nk2r_cavpo 3667 finished
# 	ranked_1.pdb *is* outside
# nk2r_cavpo 3795 finished
# 	ranked_0.pdb *is* outside
# nk2r_human 2087 finished
# 	ranked_0.pdb *is* outside
# nk2r_human 2090 finished
# 	ranked_0.pdb *is* outside
# nk2r_human 3795 finished
# 	ranked_0.pdb *is* outside
# nk2r_human 3835 finished
# 	ranked_0.pdb *is* outside
# nk3r_human 2087 finished
# 	ranked_0.pdb *is* outside
# nk3r_human 2090 finished
# 	ranked_0.pdb *is* outside
# nk3r_human 3795 finished
# 	ranked_0.pdb *is* outside
# nk3r_human 3835 finished
# 	ranked_0.pdb *is* outside
# nk3r_mouse 2087 finished
# 	ranked_0.pdb *is* outside
# nk3r_mouse 2090 finished
# 	ranked_0.pdb *is* outside
# nk3r_mouse 3795 finished
# 	ranked_0.pdb *is* outside
# nk3r_mouse 3835 finished
# 	ranked_0.pdb *is* outside
# nmbr_human 3579 finished
# 	ranked_0.pdb *is* outside
# nmbr_human 3581 finished
# 	ranked_0.pdb *is* outside
# nmbr_human 3582 finished
# 	ranked_0.pdb *is* outside
# nmbr_human 3583 finished
# 	ranked_0.pdb *is* outside
# nmbr_human 612 finished
# 	ranked_0.pdb *is* outside
# nmbr_human 613 finished
# 	ranked_0.pdb *is* outside
# nmbr_human 6175 finished
# 	ranked_0.pdb *is* outside
# nmbr_rat 6175 finished
# 	ranked_0.pdb *is* outside
# nmur1_human 1468 finished
# 	ranked_0.pdb *is* outside
# nmur1_human 1469 finished
# 	ranked_0.pdb *is* outside
# nmur1_human 1470 finished
# 	ranked_0.pdb *is* outside
# nmur1_human 3613 finished
# 	ranked_0.pdb *is* outside
# nmur1_human 3614 finished
# 	ranked_0.pdb *is* outside
# nmur1_human 3615 finished
# 	ranked_0.pdb *is* outside
# nmur2_human 1468 finished
# 	ranked_0.pdb *is* outside
# nmur2_human 1469 finished
# 	ranked_0.pdb *is* outside
# nmur2_human 1470 finished
# 	ranked_0.pdb *is* outside
# nmur2_human 3614 finished
# 	ranked_0.pdb *is* outside
# nmur2_human 3615 finished
# 	ranked_0.pdb *is* outside
# npbw1_human 1495 finished
# 	ranked_0.pdb *is* outside
# npbw1_human 1496 finished
# 	ranked_0.pdb *is* outside
# npbw1_human 1499 finished
# 	ranked_0.pdb *is* outside
# npbw1_human 1500 finished
# 	ranked_0.pdb *is* outside
# npbw1_human 3616 finished
# 	ranked_0.pdb *is* outside
# npbw1_human 3618 finished
# 	ranked_0.pdb *is* outside
# npbw1_human 3620 finished
# 	ranked_0.pdb *is* outside
# npbw1_human 3628 finished
# 	ranked_0.pdb *is* outside
# npbw1_human 3629 finished
# 	ranked_0.pdb *is* outside
# npbw1_human 3630 finished
# 	ranked_0.pdb *is* outside
# npbw1_human 3631 finished
# 	ranked_0.pdb *is* outside
# npbw2_human 1495 finished
# 	ranked_0.pdb *is* outside
# npbw2_human 1496 finished
# 	ranked_0.pdb *is* outside
# npbw2_human 1501 finished
# 	ranked_0.pdb *is* outside
# npbw2_human 1502 finished
# 	ranked_0.pdb *is* outside
# npbw2_human 3616 finished
# 	ranked_0.pdb *is* outside
# npbw2_human 3618 finished
# 	ranked_0.pdb *is* outside
# npbw2_human 3620 finished
# 	ranked_0.pdb *is* outside
# npbw2_human 3628 finished
# 	ranked_0.pdb *is* outside
# npbw2_human 3629 finished
# 	ranked_0.pdb *is* outside
# npbw2_human 3630 finished
# 	ranked_0.pdb *is* outside
# npbw2_human 3631 finished
# 	ranked_0.pdb *is* outside
# npff1_human 1479 finished
# 	ranked_0.pdb *is* outside
# npff1_human 1873 finished
# 	ranked_0.pdb *is* outside
# npff1_human 3665 finished
# 	ranked_0.pdb *is* outside
# npff1_human 3735 finished
# 	ranked_0.pdb *is* outside
# npff1_human 3736 finished
# 	ranked_0.pdb *is* outside
# npff1_human 4016 finished
# 	ranked_0.pdb *is* outside
# npff1_human 4442 finished
# 	ranked_0.pdb *is* outside
# npff1_human 4443 finished
# 	ranked_0.pdb *is* outside
# npff1_human 4444 finished
# 	ranked_0.pdb *is* outside
# npff1_human 4445 finished
# 	ranked_0.pdb *is* outside
# npff1_human 5340 finished
# 	ranked_0.pdb *is* outside
# npff2_human 1479 finished
# 	ranked_0.pdb *is* outside
# npff2_human 1873 finished
# 	ranked_0.pdb *is* outside
# npff2_human 3665 finished
# 	ranked_0.pdb *is* outside
# npff2_human 3735 finished
# 	ranked_0.pdb *is* outside
# npff2_human 3736 finished
# 	ranked_0.pdb *is* outside
# npff2_human 4016 finished
# 	ranked_0.pdb *is* outside
# npff2_human 4442 finished
# 	ranked_0.pdb *is* outside
# npff2_human 4443 finished
# 	ranked_0.pdb *is* outside
# npff2_human 5340 finished
# 	ranked_0.pdb *is* outside
# npsr1_human 1490 finished
# 	ranked_0.pdb *is* outside
# npsr1_human 1491 finished
# 	ranked_0.pdb *is* outside
# npsr1_human 1492 finished
# 	ranked_0.pdb *is* outside
# npy1r_human 1512 finished
# 	ranked_0.pdb *is* outside
# npy1r_human 1514 finished
# 	ranked_0.pdb *is* outside
# npy1r_human 1521 finished
# 	ranked_0.pdb *is* outside
# npy1r_human 3626 finished
# 	ranked_0.pdb *is* outside
# npy1r_rat 1513 finished
# 	ranked_0.pdb *is* outside
# npy1r_rat 1514 finished
# 	ranked_0.pdb *is* outside
# npy1r_rat 1515 finished
# 	ranked_0.pdb *is* outside
# npy1r_rat 1521 finished
# 	ranked_0.pdb *is* outside
# npy2r_human 1512 finished
# 	ranked_0.pdb *is* outside
# npy2r_human 1513 finished
# 	ranked_0.pdb *is* outside
# npy2r_human 1514 finished
# 	ranked_0.pdb *is* outside
# npy2r_human 1515 finished
# 	ranked_0.pdb *is* outside
# npy2r_human 1517 finished
# 	ranked_0.pdb *is* outside
# npy2r_human 1521 finished
# 	ranked_0.pdb *is* outside
# npy2r_human 3626 finished
# 	ranked_0.pdb *is* outside
# npy2r_human 3627 finished
# 	ranked_0.pdb *is* outside
# npy4r_human 1512 finished
# 	ranked_0.pdb *is* outside
# npy4r_human 1513 finished
# 	ranked_0.pdb *is* outside
# npy4r_human 1514 finished
# 	ranked_0.pdb *is* outside
# npy4r_human 1521 finished
# 	ranked_0.pdb *is* outside
# npy4r_human 3626 finished
# 	ranked_0.pdb *is* outside
# npy4r_mouse 1512 finished
# 	ranked_0.pdb *is* outside
# npy4r_mouse 1513 finished
# 	ranked_0.pdb *is* outside
# npy4r_mouse 1515 finished
# 	ranked_0.pdb *is* outside
# npy4r_rat 1512 finished
# 	ranked_0.pdb *is* outside
# npy4r_rat 1513 finished
# 	ranked_0.pdb *is* outside
# npy4r_rat 1514 finished
# 	ranked_0.pdb *is* outside
# npy4r_rat 1515 finished
# 	ranked_0.pdb *is* outside
# npy4r_rat 1521 finished
# 	ranked_0.pdb *is* outside
# npy4r_rat 1554 finished
# 	ranked_0.pdb *is* outside
# npy5r_human 1512 finished
# 	ranked_0.pdb *is* outside
# npy5r_human 1513 finished
# 	ranked_0.pdb *is* outside
# npy5r_human 1514 finished
# 	ranked_0.pdb *is* outside
# npy5r_human 1515 finished
# 	ranked_0.pdb *is* outside
# npy5r_human 1521 finished
# 	ranked_0.pdb *is* outside
# npy5r_human 1554 finished
# 	ranked_0.pdb *is* outside
# npy5r_human 3626 finished
# 	ranked_0.pdb *is* outside
# npy5r_rat 1512 finished
# 	ranked_0.pdb *is* outside
# npy5r_rat 1513 finished
# 	ranked_0.pdb *is* outside
# npy5r_rat 1515 finished
# 	ranked_0.pdb *is* outside
# npy5r_rat 1521 finished
# 	ranked_0.pdb *is* outside
# npy5r_rat 1554 finished
# 	ranked_0.pdb *is* outside
# ntr1_human 1576 finished
# 	ranked_0.pdb *is* outside
# ntr1_human 1577 finished
# ntr1_human 3625 finished
# 	ranked_0.pdb *is* outside
# ntr1_human 3830 finished
# 	ranked_0.pdb *is* outside
# ntr1_human 5303 finished
# 	ranked_0.pdb *is* outside
# ntr1_human 5304 finished
# 	ranked_0.pdb *is* outside
# ntr1_rat 1578 finished
# 	ranked_0.pdb *is* outside
# ntr1_rat 3830 finished
# 	ranked_0.pdb *is* outside
# ntr2_human 3625 finished
# 	ranked_0.pdb *is* outside
# ntr2_human 3830 finished
# 	ranked_0.pdb *is* outside
# ntr2_mouse 1578 finished
# 	ranked_0.pdb *is* outside
# ntr2_mouse 1587 finished
# 	ranked_0.pdb *is* outside
# ntr2_mouse 3830 finished
# 	ranked_0.pdb *is* outside
# ntr2_rat 1578 finished
# 	ranked_0.pdb *is* outside
# ntr2_rat 3830 finished
# 	ranked_0.pdb *is* outside
# oprd_human 1613 finished
# 	ranked_0.pdb *is* outside
# oprd_human 1619 finished
# 	ranked_0.pdb *is* outside
# oprd_human 1620 finished
# 	ranked_2.pdb *is* outside
# oprd_human 1621 finished
# 	ranked_0.pdb *is* outside
# oprd_human 1622 finished
# 	ranked_0.pdb *is* outside
# oprd_human 1623 finished
# 	ranked_0.pdb *is* outside
# oprd_human 1643 finished
# 	ranked_0.pdb *is* outside
# oprd_human 3722 finished
# 	ranked_0.pdb *is* outside
# oprd_human 3723 finished
# 	ranked_0.pdb *is* outside
# oprd_mouse 1613 finished
# 	ranked_0.pdb *is* outside
# oprd_mouse 1614 finished
# 	ranked_0.pdb *is* outside
# oprd_mouse 1643 finished
# 	ranked_0.pdb *is* outside
# oprd_mouse 3737 finished
# 	ranked_0.pdb *is* outside
# oprk_human 1619 finished
# 	ranked_0.pdb *is* outside
# oprk_human 1620 finished
# 	ranked_0.pdb *is* outside
# oprk_human 1621 finished
# 	ranked_0.pdb *is* outside
# oprk_human 1622 finished
# 	ranked_0.pdb *is* outside
# oprk_human 1643 finished
# 	ranked_0.pdb *is* outside
# oprk_human 1644 finished
# 	ranked_0.pdb *is* outside
# oprk_human 3669 finished
# 	ranked_0.pdb *is* outside
# oprk_human 3722 finished
# 	ranked_0.pdb *is* outside
# oprk_human 3723 finished
# 	ranked_0.pdb *is* outside
# oprk_human 3737 finished
# 	ranked_0.pdb *is* outside
# oprk_mouse 1620 finished
# 	ranked_0.pdb *is* outside
# oprk_mouse 1621 finished
# 	ranked_0.pdb *is* outside
# oprk_mouse 1622 finished
# 	ranked_0.pdb *is* outside
# oprk_mouse 1643 finished
# 	ranked_0.pdb *is* outside
# oprk_mouse 3737 finished
# 	ranked_0.pdb *is* outside
# oprk_rat 1613 finished
# 	ranked_0.pdb *is* outside
# oprk_rat 1614 finished
# 	ranked_0.pdb *is* outside
# oprk_rat 1619 finished
# 	ranked_0.pdb *is* outside
# oprk_rat 1620 finished
# 	ranked_0.pdb *is* outside
# oprk_rat 1622 finished
# 	ranked_0.pdb *is* outside
# oprk_rat 1643 finished
# 	ranked_0.pdb *is* outside
# oprk_rat 1644 finished
# 	ranked_0.pdb *is* outside
# oprk_rat 3737 finished
# 	ranked_0.pdb *is* outside
# oprm_human 1613 finished
# 	ranked_0.pdb *is* outside
# oprm_human 1619 finished
# 	ranked_0.pdb *is* outside
# oprm_human 1620 finished
# 	ranked_0.pdb *is* outside
# oprm_human 1621 finished
# 	ranked_0.pdb *is* outside
# oprm_human 1622 finished
# 	ranked_0.pdb *is* outside
# oprm_human 1623 finished
# 	ranked_0.pdb *is* outside
# oprm_human 1643 finished
# 	ranked_0.pdb *is* outside
# oprm_human 3722 finished
# 	ranked_0.pdb *is* outside
# oprm_human 3723 finished
# 	ranked_0.pdb *is* outside
# oprm_rat 1614 finished
# 	ranked_0.pdb *is* outside
# oprm_rat 3668 finished
# 	ranked_0.pdb *is* outside
# oprx_human 1688 finished
# 	ranked_0.pdb *is* outside
# oprx_mouse 1688 finished
# 	ranked_0.pdb *is* outside
# ox1r_human 1697 finished
# 	ranked_0.pdb *is* outside
# ox1r_human 1699 finished
# 	ranked_0.pdb *is* outside
# ox1r_human 3720 finished
# 	ranked_0.pdb *is* outside
# ox2r_human 1697 finished
# 	ranked_0.pdb *is* outside
# ox2r_human 1699 finished
# 	ranked_0.pdb *is* outside
# ox2r_human 3720 finished
# 	ranked_0.pdb *is* outside
# oxyr_human 2168 finished
# 	ranked_0.pdb *is* outside
# oxyr_human 2176 finished
# 	ranked_0.pdb *is* outside
# oxyr_rat 2176 finished
# 	ranked_0.pdb *is* outside
# par1_human 4453 finished
# par3_human 4453 finished
# 	ranked_0.pdb *is* outside
# par4_human 3570 finished
# 	ranked_0.pdb *is* outside
# par4_human 3571 finished
# 	ranked_0.pdb *is* outside
# par4_human 3572 finished
# 	ranked_0.pdb *is* outside
# par4_human 4456 finished
# pkr1_human 1866 finished
# 	ranked_0.pdb *is* outside
# pkr1_human 1867 finished
# 	ranked_0.pdb *is* outside
# pkr1_human 1868 finished
# 	ranked_0.pdb *is* outside
# pkr1_human 3715 finished
# 	ranked_0.pdb *is* outside
# pkr1_human 3716 finished
# 	ranked_0.pdb *is* outside
# pkr1_human 3717 finished
# 	ranked_0.pdb *is* outside
# pkr2_human 1866 finished
# 	ranked_0.pdb *is* outside
# pkr2_human 1867 finished
# 	ranked_0.pdb *is* outside
# pkr2_human 1868 finished
# 	ranked_0.pdb *is* outside
# pkr2_human 3715 finished
# 	ranked_0.pdb *is* outside
# pkr2_human 3716 finished
# 	ranked_0.pdb *is* outside
# pkr2_human 3717 finished
# 	ranked_0.pdb *is* outside
# prlhr_human 1521 finished
# 	ranked_0.pdb *is* outside
# prlhr_human 1871 finished
# 	ranked_0.pdb *is* outside
# prlhr_human 1872 finished
# 	ranked_0.pdb *is* outside
# prlhr_human 1873 finished
# 	ranked_0.pdb *is* outside
# prlhr_human 1874 finished
# 	ranked_0.pdb *is* outside
# prlhr_human 3738 finished
# 	ranked_0.pdb *is* outside
# q5y986_rat 11923 finished
# CEalign-Error: Your mobile selection is too short.
# 	ranked_0.pdb *is* outside
# q9erc0_rat 1521 finished
# 	ranked_0.pdb *is* outside
# qrfpr_human 3665 finished
# 	ranked_0.pdb *is* outside
# qrfpr_human 3713 finished
# 	ranked_0.pdb *is* outside
# qrfpr_human 5895 finished
# 	ranked_0.pdb *is* outside
# qrfpr_mouse 3665 finished
# 	ranked_0.pdb *is* outside
# qrfpr_mouse 3712 finished
# 	ranked_0.pdb *is* outside
# qrfpr_mouse 5896 finished
# 	ranked_0.pdb *is* outside
# qrfpr_rat 10251 finished
# 	ranked_0.pdb *is* outside
# qrfpr_rat 3665 finished
# 	ranked_0.pdb *is* outside
# rl3r1_human 1989 finished
# 	ranked_0.pdb *is* outside
# rl3r1_human 1990 finished
# CEalign-Error: Your mobile selection is too short.
# 	ranked_0.pdb *is* outside
# rl3r1_human 1997 finished
# 	ranked_0.pdb *is* outside
# rl3r1_human 2000 NOT finished
# rl3r2_human 1990 finished
# CEalign-Error: Your mobile selection is too short.
# 	ranked_0.pdb *is* outside
# rl3r2_human 1997 finished
# 	ranked_0.pdb *is* outside
# rl3r2_human 2000 NOT finished
# rl3r2_mouse 6519 NOT finished
# rxfp1_human 1988 NOT finished
# rxfp1_human 1989 NOT finished
# rxfp1_human 1990 NOT finished
# rxfp2_human 1988 finished
# 	ranked_0.pdb *is* outside
# rxfp2_human 1989 finished
# 	ranked_0.pdb *is* outside
# rxfp2_human 1990 finished
# CEalign-Error: Your mobile selection is too short.
# 	ranked_0.pdb *is* outside
# rxfp2_human 1995 finished
# 	ranked_0.pdb *is* outside
# ssr1_human 2007 finished
# 	ranked_0.pdb *is* outside
# ssr1_human 2008 finished
# 	ranked_0.pdb *is* outside
# ssr1_human 2019 finished
# 	ranked_0.pdb *is* outside
# ssr1_human 2020 finished
# 	ranked_0.pdb *is* outside
# ssr1_rat 2019 finished
# 	ranked_0.pdb *is* outside
# ssr2_human 2007 finished
# 	ranked_0.pdb *is* outside
# ssr2_human 2008 finished
# 	ranked_0.pdb *is* outside
# ssr2_human 2019 finished
# 	ranked_0.pdb *is* outside
# ssr2_human 2020 finished
# 	ranked_0.pdb *is* outside
# ssr2_mouse 2019 finished
# 	ranked_0.pdb *is* outside
# ssr2_mouse 2020 finished
# 	ranked_0.pdb *is* outside
# ssr2_rat 2019 finished
# 	ranked_0.pdb *is* outside
# ssr2_rat 2020 finished
# 	ranked_0.pdb *is* outside
# ssr3_human 2007 finished
# 	ranked_0.pdb *is* outside
# ssr3_human 2008 finished
# 	ranked_0.pdb *is* outside
# ssr3_human 2019 finished
# 	ranked_0.pdb *is* outside
# ssr3_human 2020 finished
# 	ranked_0.pdb *is* outside
# ssr3_mouse 2019 finished
# 	ranked_0.pdb *is* outside
# ssr3_mouse 2020 finished
# 	ranked_0.pdb *is* outside
# ssr3_rat 2019 finished
# 	ranked_0.pdb *is* outside
# ssr3_rat 2020 finished
# 	ranked_0.pdb *is* outside
# ssr4_human 2007 finished
# 	ranked_0.pdb *is* outside
# ssr4_human 2008 finished
# 	ranked_0.pdb *is* outside
# ssr4_human 2019 finished
# 	ranked_0.pdb *is* outside
# ssr4_human 2020 finished
# 	ranked_0.pdb *is* outside
# ssr4_rat 2019 finished
# 	ranked_0.pdb *is* outside
# ssr5_human 2007 finished
# 	ranked_0.pdb *is* outside
# ssr5_human 2008 finished
# 	ranked_0.pdb *is* outside
# ssr5_human 2019 finished
# 	ranked_0.pdb *is* outside
# ssr5_human 2020 finished
# 	ranked_0.pdb *is* outside
# ssr5_mouse 2007 finished
# 	ranked_0.pdb *is* outside
# ssr5_mouse 2008 finished
# 	ranked_0.pdb *is* outside
# ssr5_mouse 2019 finished
# 	ranked_0.pdb *is* outside
# ssr5_mouse 2020 finished
# 	ranked_0.pdb *is* outside
# ssr5_rat 2019 finished
# 	ranked_0.pdb *is* outside
# ssr5_rat 2020 finished
# 	ranked_0.pdb *is* outside
# trfr_rat 3836 finished
# 	ranked_0.pdb *is* outside
# tshr_human 3920 finished
# 	ranked_0.pdb *is* outside
# ur2r_human 2153 finished
# 	ranked_0.pdb *is* outside
# ur2r_human 2154 finished
# 	ranked_0.pdb *is* outside
# ur2r_human 2155 finished
# 	ranked_0.pdb *is* outside
# ur2r_human 2156 finished
# 	ranked_0.pdb *is* outside
# ur2r_mouse 2153 finished
# 	ranked_0.pdb *is* outside
# ur2r_mouse 2154 finished
# 	ranked_0.pdb *is* outside
# ur2r_mouse 2155 finished
# 	ranked_0.pdb *is* outside
# ur2r_rat 2153 finished
# 	ranked_0.pdb *is* outside
# ur2r_rat 2154 finished
# 	ranked_0.pdb *is* outside
# ur2r_rat 2155 finished
# 	ranked_0.pdb *is* outside
# v1ar_human 2168 finished
# 	ranked_0.pdb *is* outside
# v1ar_human 2176 finished
# 	ranked_0.pdb *is* outside
# v1ar_rat 2168 finished
# 	ranked_0.pdb *is* outside
# v1ar_rat 2176 finished
# 	ranked_0.pdb *is* outside
# v1br_human 2168 finished
# 	ranked_0.pdb *is* outside
# v1br_human 2176 finished
# 	ranked_0.pdb *is* outside
# v1br_rat 2168 finished
# 	ranked_0.pdb *is* outside
# v2r_human 2168 finished
# 	ranked_0.pdb *is* outside
# v2r_human 2176 finished
# 	ranked_0.pdb *is* outside
# xcr1_human 3647 finished
# 	ranked_0.pdb *is* outside
# xcr1_human 4370 finished
# 	ranked_0.pdb *is* outside
# xcr1_human 4446 finished
# 	ranked_0.pdb *is* outside
# xcr1_human 4447 finished
# 	ranked_0.pdb *is* outside
# '/Users/nqz918/Documents/data/code/af_arman/output_files_af23/all_chosen_pdbs.zip'

# %%
print("\n > %s passed" % len(results_data[(results_data["finished"] == True) & (results_data["outside_found"] == True)].index))
print(" > %s have not finished" % len(results_data[results_data["finished"] == False].index))
print("\t", " ".join(results_data[results_data["finished"] == False].index))
print(" > %s have no ligand on outside" % len(results_data[(results_data["outside_found"] == False) & (results_data["finished"] == True)].index))
print("\t", " ".join(results_data[(results_data["outside_found"] == False) & (results_data["finished"] == True)].index))
results_data
# Out:
#  > 713 passed
#  > 6 have not finished
# 	 rl3r1_human-2000 rl3r2_human-2000 rl3r2_mouse-6519 rxfp1_human-1988 rxfp1_human-1989 rxfp1_human-1990
#  > 17 have no ligand on outside
# 	 ccr6_human-3648 fpr1_human-1031 fpr1_human-3568 fpr1_human-3569 fpr2_human-1031 fpr2_human-3568 fpr2_human-3569 fshr_human-1157 g37l1_human-6067 gasr_human-8411 gpr37_human-6067 gpr39_human-5336 gpr39_human-5337 hrh4_human-1272 ntr1_human-1577 par1_human-4453 par4_human-4456
#                 finished     receptor ligand outside_found chosen_rank score  \
# complex
# 5ht1b_human-137     True  5ht1b_human    137          True           4  0.55
# 5ht1d_human-137     True  5ht1d_human    137          True           4  0.55
# ackr1_human-753     True  ackr1_human    753          True           0   0.8
# ackr1_human-758     True  ackr1_human    758          True           0  0.84
# ackr1_human-759     True  ackr1_human    759          True           0  0.79
# ...                  ...          ...    ...           ...         ...   ...
# v2r_human-2176      True    v2r_human   2176          True           0   0.9
# xcr1_human-3647     True   xcr1_human   3647          True           0  0.68
# xcr1_human-4370     True   xcr1_human   4370          True           0  0.64
# xcr1_human-4446     True   xcr1_human   4446          True           0  0.67
# xcr1_human-4447     True   xcr1_human   4447          True           0  0.69
#
#                 relaxed
# complex
# 5ht1b_human-137    True
# 5ht1d_human-137    True
# ackr1_human-753    True
# ackr1_human-758    True
# ackr1_human-759    True
# ...                 ...
# v2r_human-2176     True
# xcr1_human-3647    True
# xcr1_human-4370    True
# xcr1_human-4446    True
# xcr1_human-4447    True
#
# [736 rows x 7 columns]
